# %% [markdown]
# ## 강원도 10a당 생산량 예측 값 그래프

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df = pd.read_csv("data/predict/gangwon_rf.csv", encoding = "cp949")
df.columns = ["RF 모델 강원도 10a당 생산량 예측 값", "연도"]

# %% [markdown]
# ## 그래프 생성하는 코드

# %%
df.plot(x = '연도', y = 'RF 모델 강원도 10a당 생산량 예측 값', rot = 45, colormap ="summer")
plt.ylim(1200,1700)
# Out:
# (1200.0, 1700.0)
